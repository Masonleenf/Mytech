# %%
# 1. data_manager.py 파일 읽어서 263번째 줄 근처 확인
with open('data_manager.py', 'r', encoding='utf-8') as f:
    lines = f.readlines()

print("data_manager.py 파일의 260-270번째 줄:")
for i in range(259, min(270, len(lines))):  # 260-270번째 줄 (인덱스는 259-269)
    print(f"{i+1:3d}: {lines[i].rstrip()}")

print(f"\n총 줄 수: {len(lines)}")

# 2. pd.notna(ret) 패턴이 있는 줄들 찾기
print("\n=== pd.notna 패턴이 있는 줄들 ===")
for i, line in enumerate(lines):
    if 'pd.notna(' in line or 'pd.notna(' in line:
        print(f"{i+1:3d}: {line.rstrip()}")

# 3. create_synthetic_indices 함수 내용 확인
print("\n=== create_synthetic_indices 함수 시작 부분 ===")
in_function = False
for i, line in enumerate(lines):
    if 'def create_synthetic_indices' in line:
        in_function = True
        start_line = i
    
    if in_function and i < start_line + 50:  # 처음 50줄만
        print(f"{i+1:3d}: {line.rstrip()}")
        if line.strip() == '' and i > start_line + 10:  # 함수 끝나면 중단
            break

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
from datetime import datetime

# MongoDB 연결
MONGO_URI = "mongodb+srv://rator9521_db_user:qwe343434@cluster0.d126rkt.mongodb.net/"
client = MongoClient(MONGO_URI)
db = client["etf_database"]

def test_create_synthetic_indices_debug():
    """create_synthetic_indices 함수를 단계별로 디버깅"""
    print("=== create_synthetic_indices 디버깅 시작 ===")
    
    # etf_master에서 데이터 로드
    master_list = list(db['etf_master'].find({}, {'_id': 0}))
    master_df = pd.DataFrame(master_list)
    master_df['상장일'] = pd.to_datetime(master_df['상장일'])
    
    # fund_prices에서 데이터 로드하여 수익률 계산
    price_data = {}
    print("ETF 수익률 계산 중...")
    
    error_tickers = []
    success_count = 0
    
    for ticker in master_df['ticker'].unique():
        doc = db['fund_prices'].find_one({'ticker': ticker})
        if not doc or 'prices' not in doc:
            continue
        
        try:
            # MongoDB 데이터를 DataFrame으로 변환
            df = pd.DataFrame(doc['prices'])
            df['Date'] = pd.to_datetime(df['Date'])
            df = df.set_index('Date').sort_index()
            df['Close'] = pd.to_numeric(df['Close'], errors='coerce')
            df = df.dropna(subset=['Close'])
            
            if len(df) > 1:
                returns = df['Close'].pct_change()
                
                # 중복 인덱스 확인
                if returns.index.duplicated().any():
                    print(f"⚠️ {ticker}: 중복 날짜 발견")
                    print(f"   중복 날짜들: {returns.index[returns.index.duplicated()].tolist()}")
                    returns = returns[~returns.index.duplicated(keep='first')]
                
                price_data[ticker] = returns
                success_count += 1
            
        except Exception as e:
            error_tickers.append((ticker, str(e)))
            print(f"❌ {ticker} 처리 오류: {e}")
    
    print(f"✅ 성공: {success_count}개, ❌ 실패: {len(error_tickers)}개")
    
    # 첫 번째 코드로 실제 합성지수 생성 테스트
    unique_codes = master_df['code'].dropna().unique()
    first_code = unique_codes[0]  # 첫 번째 코드만 테스트
    
    print(f"\n=== '{first_code}' 합성지수 생성 테스트 ===")
    
    try:
        group_df = master_df[master_df['code'] == first_code]
        print(f"그룹 ETF 개수: {len(group_df)}")
        print(f"그룹 ETF들: {group_df['ticker'].tolist()}")
        
        # 실제 데이터 시작일 찾기
        actual_start_date = None
        valid_tickers = []
        
        for ticker in group_df['ticker']:
            if ticker in price_data and not price_data[ticker].empty:
                first_valid_date = price_data[ticker].first_valid_index()
                if first_valid_date is not None:
                    valid_tickers.append(ticker)
                    if actual_start_date is None or first_valid_date < actual_start_date:
                        actual_start_date = first_valid_date
        
        print(f"유효한 ticker 개수: {len(valid_tickers)}")
        print(f"실제 시작일: {actual_start_date}")
        
        if actual_start_date is None:
            print(f"❌ '{first_code}' 데이터 없음")
            return
        
        # 날짜 범위 생성 (처음 10일만 테스트)
        end_date = actual_start_date + pd.Timedelta(days=10)
        date_range = pd.date_range(start=actual_start_date, end=end_date, freq='B')[:10]
        
        print(f"테스트 날짜 범위: {len(date_range)}일")
        
        daily_avg_returns = []
        error_dates = []
        
        for i, dt in enumerate(date_range):
            print(f"\n--- 날짜 {i+1}/{len(date_range)}: {dt.date()} ---")
            
            active_etfs = group_df[group_df['상장일'] <= dt]
            print(f"활성 ETF 개수: {len(active_etfs)}")
            
            returns_for_day = []
            
            for ticker in active_etfs['ticker']:
                if ticker in price_data and dt in price_data[ticker].index:
                    try:
                        ret = price_data[ticker].loc[dt]
                        print(f"  {ticker}: ret = {ret} (타입: {type(ret)})")
                        
                        # 여기가 문제의 핵심 부분!
                        if isinstance(ret, pd.Series):
                            print(f"    ⚠️ Series 발견! 길이: {len(ret)}")
                            print(f"    Series 내용: {ret.tolist()}")
                            if len(ret) > 0:
                                ret = ret.iloc[0]
                                print(f"    -> 변환된 값: {ret}")
                            else:
                                print(f"    -> 빈 Series, 건너뜀")
                                continue
                        
                        # notna 체크
                        if pd.notna(ret) and np.isfinite(ret):
                            returns_for_day.append(float(ret))
                            print(f"    ✅ 추가됨: {float(ret)}")
                        else:
                            print(f"    ⚠️ NaN 또는 무한대, 건너뜀")
                    
                    except Exception as e:
                        error_dates.append((dt, ticker, str(e)))
                        print(f"    ❌ 에러: {e}")
            
            avg_return = sum(returns_for_day) / len(returns_for_day) if returns_for_day else 0.0
            daily_avg_returns.append(avg_return)
            print(f"  일평균 수익률: {avg_return} (개별값 {len(returns_for_day)}개)")
        
        print(f"\n=== 테스트 완료 ===")
        print(f"에러 발생 날짜: {len(error_dates)}개")
        for date, ticker, error in error_dates:
            print(f"  {date.date()} {ticker}: {error}")
        
        # 실제 지수 계산까지 해보기
        if daily_avg_returns:
            index_df = pd.DataFrame({'Date': date_range, 'return': daily_avg_returns})
            index_df.iloc[0, index_df.columns.get_loc('return')] = 0.0
            index_df['close'] = 100 * (1 + index_df['return']).cumprod()
            
            print(f"\n최종 지수 계산 결과:")
            print(index_df.head())
        
    except Exception as e:
        print(f"❌ 전체 테스트 실패: {e}")
        import traceback
        traceback.print_exc()

# 실행
test_create_synthetic_indices_debug()
# Out:
# === create_synthetic_indices 디버깅 시작 ===
# ETF 수익률 계산 중...
# ⚠️ 069500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 069660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 091230.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 091170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 091160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 091180.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 091220.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 098560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 099140.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 100910.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 101280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 102110.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 102780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 102960.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 102970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 104530.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 104520.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 105010.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 105190.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 105780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 108590.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 108450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 114100.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 114260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 114460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 114470.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 114820.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 117460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 117690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 117680.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 117700.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 122090.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 122260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 130730.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 130680.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 131890.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 132030.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 133690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 137610.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 138230.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 138520.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 138540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 138530.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 138920.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 138910.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139240.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139230.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139250.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139220.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139290.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 139320.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 136340.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 140570.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 140580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 140700.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 140710.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 140950.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 144600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 143850.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 143860.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 145850.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 148020.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 148070.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 147970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 150460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 152100.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 152380.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 152870.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 153130.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 153270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 156080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 157490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 157500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 157450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 159800.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 161510.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 166400.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 168580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 160580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 169950.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 174360.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 174350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 181480.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 182480.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 183700.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 183710.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 185680.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 189400.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 190620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 192090.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 192720.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 182490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 195930.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 195920.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 195970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 195980.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 196230.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 200030.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 200250.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 203780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 210780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 211900.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 211560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 213610.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 213630.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 214980.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 215620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 218420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 219480.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 219390.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 220130.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 223190.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 226380.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 226490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 226980.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 227550.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 227560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 227570.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 227540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 227830.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 229200.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 228810.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 228800.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 228790.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 229720.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 228820.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 232080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 237440.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 237350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 237370.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 234310.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 238670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 238720.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 239660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 241180.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 241390.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 244660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 244670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 244580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 244620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 245360.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 248270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 245340.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 245350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 245710.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 250730.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 251600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 251590.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 251350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 252000.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 252650.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 253290.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 253280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 256440.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 256750.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 256450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 261060.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 261070.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 261220.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 261240.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 261920.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 261140.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 265690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2022-03-04 00:00:00'), Timestamp('2022-03-04 00:00:00'), Timestamp('2022-03-04 00:00:00')]
# ⚠️ 266360.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 266370.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 266550.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 266410.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 266420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 266390.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 266160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 267440.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 269530.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 269420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 269540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 269370.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 271060.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 270810.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 272580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 273130.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 272910.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 273140.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 272560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 272570.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 270800.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 275280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 275300.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 275290.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 276000.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 275980.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 276970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 276650.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 276990.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 277540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 277640.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 277650.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 277630.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 278620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 279530.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 280320.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 280920.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 279540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 281990.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 278540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 280930.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 278530.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 284430.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 284980.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 287180.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 285690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 283580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 289670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 289260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 289250.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 289480.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 290080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 290130.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 291130.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 291890.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 292730.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 292190.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 292160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 292050.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 292500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 293180.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 292150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 292560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 295040.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 294400.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 295000.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 298340.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 298770.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 301400.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 302190.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 300950.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 300610.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 300640.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 302450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 304770.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 304760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 305080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 304940.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 305540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 304660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 305720.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 305050.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 308620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 309230.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 307510.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 307520.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 310970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 310960.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 310080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 314700.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 314250.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 315270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 315960.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 316670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 315930.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 316300.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 319640.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 322400.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 322410.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 325020.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 325010.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 321410.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 326230.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 326240.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 328370.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 329650.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 329670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 329660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 329200.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 329750.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 332620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 332610.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 332940.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 332930.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 332500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 334690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 336160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 337160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 337150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 337140.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 337120.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 346000.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 354500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 354350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 352560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 352540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 354240.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 341850.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 357870.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 356540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 359210.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 360200.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 360750.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 360140.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 361580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 360150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 363510.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 363580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 363570.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 365040.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 364690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 364970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 364980.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 364990.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 365000.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 364960.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 365780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 367760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 367740.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 367770.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 367380.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 368590.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 368190.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 368680.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 371450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 371460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 371470.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 372330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 371160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 371870.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 371150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 373790.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 373490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 375270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 375770.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 376410.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 375760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 377990.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 381560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 380340.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 381570.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 381170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 379780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 381180.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 379800.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 379790.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 379810.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385590.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385710.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385520.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385510.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 387270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385720.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 387280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385550.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 385540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 388280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 388420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 390400.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 390390.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 391670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 394670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 394660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 394350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 395170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 395160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 395750.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 395280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 395290.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 395150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 395760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 395270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 391600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 396500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 396510.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 396520.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 397420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 399110.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 400970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 402460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 401170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 401470.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 403790.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 399580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 402970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 404650.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 404540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 404260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 404120.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 407160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-16 00:00:00'), Timestamp('2025-09-16 00:00:00'), Timestamp('2025-09-16 00:00:00')]
# ⚠️ 407830.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 407170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-16 00:00:00'), Timestamp('2025-09-16 00:00:00'), Timestamp('2025-09-16 00:00:00')]
# ⚠️ 407820.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 407300.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 407310.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 411540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 411060.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 410870.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 411860.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 411050.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-08-13 00:00:00'), Timestamp('2025-08-13 00:00:00'), Timestamp('2025-08-13 00:00:00')]
# ⚠️ 413220.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 411420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 412770.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 413930.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 415760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 416090.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 414780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 415340.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 415920.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 417630.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 414270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 417450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 419650.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 418670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 419890.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 419420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 419430.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 422260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 421320.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 422420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 423170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 424460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 426330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 423160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 426020.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 426030.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 426150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 428560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 427120.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 428510.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 429000.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 429010.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 429740.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 429760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 430500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 432840.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 429980.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 432600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 433330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 434960.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 433500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 434730.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 433220.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 435040.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 433980.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 435550.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 435530.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 433970.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 433880.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 434060.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 435540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 433870.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-16 00:00:00'), Timestamp('2025-09-16 00:00:00'), Timestamp('2025-09-16 00:00:00')]
# ⚠️ 433860.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-08-19 00:00:00'), Timestamp('2025-08-19 00:00:00'), Timestamp('2025-08-19 00:00:00')]
# ⚠️ 433250.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 435420.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 437370.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 437350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 436140.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 437070.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 437080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 438900.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 438740.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 440650.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 438330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 439860.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 439870.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 440640.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 438080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 440910.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 438100.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 440340.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 438560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 438570.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 441540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 442090.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 441330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 442580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 441680.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 442570.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 442550.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 442560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 441800.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 441640.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 444490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 442320.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 444200.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 445910.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 442260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 445690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 446700.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 445150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 446720.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 445290.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 447430.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448570.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 446770.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448290.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448300.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 447660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448630.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 447770.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 447620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449190.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449180.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 448100.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449770.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 450190.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 450180.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449680.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 449450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 451000.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 451060.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 451150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 450910.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 446690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 451530.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 451540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 451600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 452440.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453060.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453850.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453010.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 452360.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453650.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453630.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453640.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 455030.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 454180.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453950.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 454780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453870.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 455660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 454320.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 453810.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 455850.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 455860.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 456880.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 456250.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 455890.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 456610.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 456200.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 457480.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 455960.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 456600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 458210.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 457690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 457700.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 458250.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 458030.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 458260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 459580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 459560.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 458760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 458730.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 457930.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 458750.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 457990.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 460270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 459750.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 460660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 460280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 459790.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461950.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 460960.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461340.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 462010.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461900.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 462340.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 463250.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 463690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 464060.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 463680.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 463640.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 463290.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 462900.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 463300.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 462540.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-05 00:00:00'), Timestamp('2025-09-05 00:00:00'), Timestamp('2025-09-05 00:00:00')]
# ⚠️ 463050.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 464310.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 464240.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 464600.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 464470.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 464610.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 464930.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 464920.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 465580.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 465330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 465660.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 465670.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 466400.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-08-25 00:00:00'), Timestamp('2025-08-25 00:00:00'), Timestamp('2025-08-25 00:00:00')]
# ⚠️ 466920.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 466930.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 467940.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 466950.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 469150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 466940.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 467620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 469160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 469170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 466810.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 468630.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 468820.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 468380.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 468370.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 469060.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 469070.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 469050.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 461500.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 469790.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 469830.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 471460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 471230.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 470310.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 471990.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 471760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 471040.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 471780.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 472170.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 472160.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 473290.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 472350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 472150.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 472720.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 472830.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 473440.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 473490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 472840.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 472870.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 473460.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 473330.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 473590.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 474390.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 474590.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 474220.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 474800.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 474920.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475070.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 473640.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475270.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475280.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475050.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475630.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475300.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476070.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475310.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475380.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476850.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476310.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475350.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476260.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476550.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476000.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476690.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476450.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476810.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 475720.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476800.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476760.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476750.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 476030.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 477490.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 477080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 477050.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 479080.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 479620.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 479850.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 480310.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 480020.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 478150.KS: 중복 날짜 발견
# ...
# ⚠️ 0018Z0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0026S0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0019K0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0025N0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 498610.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0000H0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0035T0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0038A0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0036R0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0040S0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0041D0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0036Z0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0043B0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0040X0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0040Y0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0036D0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0046A0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0048K0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0047N0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0048J0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0046Y0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0047R0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0049M0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0047P0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0047A0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0049K0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0043Y0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0052D0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0051G0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0051A0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0053L0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0052T0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0028X0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0057H0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0052S0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0064K0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0065G0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0067Y0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0067V0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0066W0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0072R0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0068M0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0060H0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0061Z0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0069M0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0073X0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0074K0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0080X0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0079X0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0080G0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0083S0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0085P0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0085N0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0084D0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0078V0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0082V0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0053M0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0086C0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0087F0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0082F0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0086B0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0088N0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0089C0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ⚠️ 0089D0.KS: 중복 날짜 발견
#    중복 날짜들: [Timestamp('2025-09-19 00:00:00')]
# ✅ 성공: 906개, ❌ 실패: 0개
#
# === 'SK09' 합성지수 생성 테스트 ===
# 그룹 ETF 개수: 67
# 그룹 ETF들: ['069500.KS', '069660.KS', '102110.KS', '105190.KS', '108590.KS', '114460.KS', '114470.KS', '114820.KS', '122090.KS', '140950.KS', '148020.KS', '152100.KS', '152870.KS', '153270.KS', '156080.KS', '159800.KS', '215620.KS', '226490.KS', '227830.KS', '237350.KS', '252000.KS', '252650.KS', '277630.KS', '278540.KS', '278530.KS', '284430.KS', '292730.KS', '292190.KS', '292160.KS', '292050.KS', '292500.KS', '293180.KS', '295040.KS', '294400.KS', '302450.KS', '304760.KS', '305050.KS', '310970.KS', '310960.KS', '328370.KS', '332940.KS', '332930.KS', '332500.KS', '337160.KS', '359210.KS', '361580.KS', '365040.KS', '364690.KS', '385720.KS', '391670.KS', '403790.KS', '407310.KS', '411540.KS', '434960.KS', '433250.KS', '441800.KS', '442260.KS', '448570.KS', '448100.KS', '451060.KS', '472720.KS', '472840.KS', '476850.KS', '491700.KS', '491220.KS', '494890.KS', '0007N0.KS']
# 유효한 ticker 개수: 67
# 실제 시작일: 2015-09-23 00:00:00
# 테스트 날짜 범위: 8일
#
# --- 날짜 1/8: 2015-09-23 ---
# 활성 ETF 개수: 19
#   069500.KS: ret = -0.013224181360201537 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.013224181360201537
#   069660.KS: ret = -0.012366380213791661 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.012366380213791661
#   102110.KS: ret = -0.012599748005039935 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.012599748005039935
#   105190.KS: ret = -0.013827781269641681 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.013827781269641681
#   108590.KS: ret = -0.01323955316508063 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.01323955316508063
#   114460.KS: ret = 0.00032955133939083225 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00032955133939083225
#   114470.KS: ret = 0.000766179917072396 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.000766179917072396
#   114820.KS: ret = 0.0013666803334699829 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0013666803334699829
#   122090.KS: ret = -0.01597552685248127 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.01597552685248127
#   140950.KS: ret = -0.01846670397313932 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.01846670397313932
#   148020.KS: ret = -0.011306532663316604 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.011306532663316604
#   152100.KS: ret = -0.011722838601632812 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.011722838601632812
#   152870.KS: ret = -0.011647254575707144 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.011647254575707144
#   153270.KS: ret = -0.01855496204666851 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.01855496204666851
#   156080.KS: ret = -0.009842519685039353 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.009842519685039353
#   159800.KS: ret = -0.01104815864022668 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.01104815864022668
#   215620.KS: ret = -0.020708697653014307 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.020708697653014307
#   226490.KS: ret = -0.015664477008590194 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.015664477008590194
#   227830.KS: ret = nan (타입: <class 'numpy.float64'>)
#     ⚠️ NaN 또는 무한대, 건너뜀
#   일평균 수익률: -0.01154071689575769 (개별값 18개)
#
# --- 날짜 2/8: 2015-09-24 ---
# 활성 ETF 개수: 19
#   069500.KS: ret = 0.00021272069772382274 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00021272069772382274
#   069660.KS: ret = -0.0021222410865874286 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0021222410865874286
#   102110.KS: ret = -0.0006380263717566947 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0006380263717566947
#   105190.KS: ret = -0.0021244954323348386 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0021244954323348386
#   108590.KS: ret = -0.0012578616352201255 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0012578616352201255
#   114460.KS: ret = 0.0 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0
#   114470.KS: ret = -0.0004053141184418019 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0004053141184418019
#   114820.KS: ret = -0.0005004321914380272 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0005004321914380272
#   122090.KS: ret = 0.0 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0
#   140950.KS: ret = -0.0005701254275940482 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0005701254275940482
#   148020.KS: ret = -0.0021177467174925413 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0021177467174925413
#   152100.KS: ret = -0.003177292946409671 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.003177292946409671
#   152870.KS: ret = -0.002946127946127919 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.002946127946127919
#   153270.KS: ret = -0.0005729017473503628 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0005729017473503628
#   156080.KS: ret = -0.006958250497017926 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.006958250497017926
#   159800.KS: ret = -0.0017187052420509774 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0017187052420509774
#   215620.KS: ret = 0.00328947368421062 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00328947368421062
#   226490.KS: ret = -0.0010266940451745254 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0010266940451745254
#   227830.KS: ret = -0.0015220700152207556 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0015220700152207556
#   일평균 수익률: -0.001271373212541221 (개별값 19개)
#
# --- 날짜 3/8: 2015-09-25 ---
# 활성 ETF 개수: 19
#   일평균 수익률: 0.0 (개별값 0개)
#
# --- 날짜 4/8: 2015-09-28 ---
# 활성 ETF 개수: 19
#   일평균 수익률: 0.0 (개별값 0개)
#
# --- 날짜 5/8: 2015-09-29 ---
# 활성 ETF 개수: 19
#   일평균 수익률: 0.0 (개별값 0개)
#
# --- 날짜 6/8: 2015-09-30 ---
# 활성 ETF 개수: 19
#   069500.KS: ret = 0.005529561888558021 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.005529561888558021
#   069660.KS: ret = 0.0040408336877924 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0040408336877924
#   102110.KS: ret = 0.006384337092998571 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.006384337092998571
#   105190.KS: ret = 0.008728975942090766 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.008728975942090766
#   108590.KS: ret = 0.011544920235096567 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.011544920235096567
#   114460.KS: ret = 0.0004706325301204739 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0004706325301204739
#   114470.KS: ret = 0.0024328707875291844 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0024328707875291844
#   114820.KS: ret = 0.0023213472917615885 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0023213472917615885
#   122090.KS: ret = 0.011053540587219413 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.011053540587219413
#   140950.KS: ret = 0.01169423844837425 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.01169423844837425
#   148020.KS: ret = 0.008701188455008557 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.008701188455008557
#   152100.KS: ret = 0.013387165320867034 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.013387165320867034
#   152870.KS: ret = 0.013085690164626351 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.013085690164626351
#   153270.KS: ret = 0.012324448265978782 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.012324448265978782
#   156080.KS: ret = 0.007507507507507505 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.007507507507507505
#   159800.KS: ret = 0.0031563845050215367 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0031563845050215367
#   215620.KS: ret = 0.00936768149882905 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00936768149882905
#   226490.KS: ret = 0.00770811921891057 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00770811921891057
#   227830.KS: ret = 0.007367886178861749 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.007367886178861749
#   일평균 수익률: 0.007726701558271177 (개별값 19개)
#
# --- 날짜 7/8: 2015-10-01 ---
# 활성 ETF 개수: 19
#   069500.KS: ret = 0.010998307952622577 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.010998307952622577
#   069660.KS: ret = 0.017157381910612113 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.017157381910612113
#   102110.KS: ret = 0.009727215056037242 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.009727215056037242
#   105190.KS: ret = 0.01139721401435212 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.01139721401435212
#   108590.KS: ret = 0.007055405685826965 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.007055405685826965
#   114460.KS: ret = 0.0007526578229373193 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0007526578229373193
#   114470.KS: ret = -0.0005842696629213551 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0005842696629213551
#   114820.KS: ret = -0.0004087007856137248 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0004087007856137248
#   122090.KS: ret = 0.010249402118209794 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.010249402118209794
#   140950.KS: ret = 0.007893994925288972 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.007893994925288972
#   148020.KS: ret = 0.009467704607616145 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.009467704607616145
#   152100.KS: ret = 0.005032501572656667 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.005032501572656667
#   152870.KS: ret = 0.006458333333333233 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.006458333333333233
#   153270.KS: ret = 0.007644394110985386 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.007644394110985386
#   156080.KS: ret = 0.014406358668653807 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.014406358668653807
#   159800.KS: ret = 0.012013729977116805 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.012013729977116805
#   215620.KS: ret = 0.00603248259860778 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00603248259860778
#   226490.KS: ret = 0.00994390617032126 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00994390617032126
#   227830.KS: ret = 0.00832282471626744 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00832282471626744
#   일평균 수익률: 0.00808214972594266 (개별값 19개)
#
# --- 날짜 8/8: 2015-10-02 ---
# 활성 ETF 개수: 19
#   069500.KS: ret = -0.0064853556485355845 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0064853556485355845
#   069660.KS: ret = -0.010204081632653073 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.010204081632653073
#   102110.KS: ret = -0.0064921465968585945 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0064921465968585945
#   105190.KS: ret = -0.009390651085141921 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.009390651085141921
#   108590.KS: ret = -0.007005975685143162 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.007005975685143162
#   114460.KS: ret = 0.0 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0
#   114470.KS: ret = 0.0001349102846606165 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.0001349102846606165
#   114820.KS: ret = 0.00022714882791197155 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: 0.00022714882791197155
#   122090.KS: ret = -0.009807237064592522 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.009807237064592522
#   140950.KS: ret = -0.006153846153846176 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.006153846153846176
#   148020.KS: ret = -0.0064610254272613465 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0064610254272613465
#   152100.KS: ret = -0.005633215105361966 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.005633215105361966
#   152870.KS: ret = -0.006623887393914285 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.006623887393914285
#   153270.KS: ret = -0.006462489463332388 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.006462489463332388
#   156080.KS: ret = -0.002938295788442735 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.002938295788442735
#   159800.KS: ret = -0.0033917467495759857 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0033917467495759857
#   215620.KS: ret = -0.0036900369003689537 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0036900369003689537
#   226490.KS: ret = -0.005806614491290052 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.005806614491290052
#   227830.KS: ret = -0.0047523761880940985 (타입: <class 'numpy.float64'>)
#     ✅ 추가됨: -0.0047523761880940985
#   일평균 수익률: -0.005312469592728434 (개별값 19개)
#
# === 테스트 완료 ===
# 에러 발생 날짜: 0개
#
# 최종 지수 계산 결과:
#         Date    return       close
# 0 2015-09-23  0.000000  100.000000
# 1 2015-09-24 -0.001271   99.872863
# 2 2015-09-25  0.000000   99.872863
# 3 2015-09-28  0.000000   99.872863
# 4 2015-09-29  0.000000   99.872863

# %%
#!/usr/bin/env python3
# backend_test.py - 백엔드 API 동작 확인

import requests
import json
from datetime import datetime

# 백엔드 서버 URL
BASE_URL = "http://127.0.0.1:8000"

def test_api_endpoints():
    """주요 API 엔드포인트 테스트"""
    print("🔥 백엔드 API 테스트 시작")
    print("=" * 60)
    
    # 1. 서버 상태 확인
    print("\n1. 서버 상태 확인")
    try:
        response = requests.get(f"{BASE_URL}/health", timeout=5)
        if response.status_code == 200:
            print("✅ 서버 정상 작동")
            print(f"   응답: {response.json()}")
        else:
            print("❌ 서버 응답 실패")
            return False
    except Exception as e:
        print(f"❌ 서버 연결 실패: {e}")
        return False
    
    # 2. ETF 자산 목록 확인
    print("\n2. ETF 자산 목록 확인")
    try:
        response = requests.get(f"{BASE_URL}/api/assets", timeout=10)
        if response.status_code == 200:
            data = response.json()
            print(f"✅ ETF 자산 목록: {len(data)}개")
            if len(data) > 0:
                sample_etf = data[0]
                print(f"   샘플 ETF: {sample_etf.get('한글종목약명', 'N/A')} ({sample_etf.get('ticker', 'N/A')})")
                test_ticker = sample_etf.get('ticker', sample_etf.get('단축코드', ''))
                test_code = sample_etf.get('code', '')
            else:
                print("❌ ETF 데이터 없음")
                return False
        else:
            print(f"❌ ETF 목록 조회 실패: {response.status_code}")
            return False
    except Exception as e:
        print(f"❌ ETF 목록 조회 에러: {e}")
        return False
    
    # 3. 사이클 분석 가능한 코드 확인
    print("\n3. 사이클 분석 가능한 코드 확인")
    try:
        response = requests.get(f"{BASE_URL}/api/cycle-codes", timeout=10)
        if response.status_code == 200:
            data = response.json()
            codes = data.get('codes', [])
            print(f"✅ 분석 가능한 코드: {len(codes)}개")
            if len(codes) > 0:
                test_code = codes[0]['code']
                print(f"   테스트 코드: {test_code} ({codes[0].get('name', 'N/A')})")
            else:
                print("❌ 분석 가능한 코드 없음")
                return False
        else:
            print(f"❌ 코드 목록 조회 실패: {response.status_code}")
            return False
    except Exception as e:
        print(f"❌ 코드 목록 조회 에러: {e}")
        return False
    
    # 4. ETF 가격 정보 테스트
    print(f"\n4. ETF 가격 정보 테스트 ({test_ticker})")
    try:
        response = requests.get(f"{BASE_URL}/api/etf/{test_ticker}/price", timeout=10)
        if response.status_code == 200:
            data = response.json()
            print("✅ ETF 가격 정보 조회 성공")
            if 'data' in data:
                price_data = data['data']
                print(f"   현재가: {price_data.get('current_price')}")
                print(f"   변화율: {price_data.get('price_change_rate')}%")
            else:
                print("   가격 데이터 없음")
        else:
            print(f"❌ ETF 가격 조회 실패: {response.status_code}")
    except Exception as e:
        print(f"❌ ETF 가격 조회 에러: {e}")
    
    # 5. 사이클 분석 데이터 테스트
    print(f"\n5. 사이클 분석 데이터 테스트 ({test_code})")
    try:
        response = requests.get(f"{BASE_URL}/api/cycle-analysis/{test_code}?time_range=3개월", timeout=15)
        if response.status_code == 200:
            data = response.json()
            print("✅ 사이클 분석 데이터 조회 성공")
            if 'data' in data:
                cycle_data = data['data']
                print(f"   데이터 키: {list(cycle_data.keys())}")
                if 'historical_data' in cycle_data:
                    print(f"   히스토리 데이터: {len(cycle_data['historical_data'])}개")
                if 'prediction_data' in cycle_data:
                    print(f"   예측 데이터: {len(cycle_data['prediction_data'])}개")
            else:
                print("   사이클 데이터 없음")
        else:
            print(f"❌ 사이클 분석 실패: {response.status_code}")
            if response.text:
                print(f"   에러: {response.text[:200]}")
    except Exception as e:
        print(f"❌ 사이클 분석 에러: {e}")
    
    # 6. 차트 데이터 테스트
    print(f"\n6. 차트 데이터 테스트 ({test_code})")
    try:
        response = requests.get(f"{BASE_URL}/api/cycle-analysis/{test_code}/chart-data?time_range=3개월", timeout=15)
        if response.status_code == 200:
            data = response.json()
            print("✅ 차트 데이터 조회 성공")
            if 'data' in data and 'chart_data' in data['data']:
                chart_data = data['data']['chart_data']
                print(f"   차트 데이터: {len(chart_data)}개")
                if len(chart_data) > 0:
                    sample = chart_data[0]
                    print(f"   샘플 데이터 키: {list(sample.keys())}")
        else:
            print(f"❌ 차트 데이터 실패: {response.status_code}")
    except Exception as e:
        print(f"❌ 차트 데이터 에러: {e}")
    
    # 7. 테이블 데이터 테스트
    print(f"\n7. 테이블 데이터 테스트 ({test_code})")
    try:
        response = requests.get(f"{BASE_URL}/api/cycle-table/{test_code}", timeout=15)
        if response.status_code == 200:
            data = response.json()
            print("✅ 테이블 데이터 조회 성공")
            if 'data' in data and 'tables' in data['data']:
                tables = data['data']['tables']
                print(f"   테이블 개수: {len(tables)}")
                for table_name in tables.keys():
                    print(f"   - {table_name}")
        else:
            print(f"❌ 테이블 데이터 실패: {response.status_code}")
    except Exception as e:
        print(f"❌ 테이블 데이터 에러: {e}")
    
    # 8. 패턴 데이터 테스트
    print(f"\n8. 패턴 데이터 테스트 ({test_code})")
    try:
        response = requests.get(f"{BASE_URL}/api/cycle-analysis/{test_code}/pattern-data", timeout=15)
        if response.status_code == 200:
            data = response.json()
            print("✅ 패턴 데이터 조회 성공")
            if 'data' in data and 'pattern_data' in data['data']:
                pattern_data = data['data']['pattern_data']
                print(f"   패턴 데이터: {type(pattern_data)}")
        else:
            print(f"❌ 패턴 데이터 실패: {response.status_code}")
    except Exception as e:
        print(f"❌ 패턴 데이터 에러: {e}")
    
    print("\n" + "=" * 60)
    print("🎯 백엔드 API 테스트 완료")
    print("=" * 60)
    
    return True

if __name__ == "__main__":
    test_api_endpoints()
# Out:
# 🔥 백엔드 API 테스트 시작
# ============================================================
#
# 1. 서버 상태 확인
# ✅ 서버 정상 작동
#    응답: {'message': 'API 서버가 정상 작동 중입니다.', 'status': 'healthy'}
#
# 2. ETF 자산 목록 확인
# ✅ ETF 자산 목록: 1027개
#    샘플 ETF: KODEX 200 (069500.KS)
#
# 3. 사이클 분석 가능한 코드 확인
# ✅ 분석 가능한 코드: 85개
#    테스트 코드: AI01 (TIGER S&P글로벌인프라(합성))
#
# 4. ETF 가격 정보 테스트 (069500.KS)
# ✅ ETF 가격 정보 조회 성공
#    현재가: 47045.0
#    변화율: -2.4%
#
# 5. 사이클 분석 데이터 테스트 (AI01)
# ✅ 사이클 분석 데이터 조회 성공
#    데이터 키: ['analysis_summary', 'code_info', 'cycle_patterns', 'generated_at', 'historical_data', 'prediction_data', 'time_range']
#    히스토리 데이터: 65개
#    예측 데이터: 45개
#
# 6. 차트 데이터 테스트 (AI01)
# ✅ 차트 데이터 조회 성공
#    차트 데이터: 0개
#
# 7. 테이블 데이터 테스트 (AI01)
# ✅ 테이블 데이터 조회 성공
#    테이블 개수: 3
#    - component_analysis
#    - cycle_summary
#    - prediction_summary
#
# 8. 패턴 데이터 테스트 (AI01)
# ✅ 패턴 데이터 조회 성공
#    패턴 데이터: <class 'list'>
#
# ============================================================
# 🎯 백엔드 API 테스트 완료
# ============================================================
